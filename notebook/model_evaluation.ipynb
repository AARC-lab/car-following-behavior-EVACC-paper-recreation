# %%
import pandas as pd
import joblib
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
data_path = "../data/combined_data_polester.csv"

# %%
# Load your dataset
df = pd.read_csv(data_path)

# Convert km/h to m/s
df["v_follower"] = df["Smooth Speed Follower"] * (1000 / 3600)
df["v_leader"] = df["Smooth Speed Leader"] * (1000 / 3600)
df.head()
# Out:
#    Unnamed: 0     Time  Speed Follower  Speed Leader  Smooth Speed Follower  \
# 0           0  1680.00          86.210        86.140                86.2380
# 1           1  1680.02          86.230        86.140                86.2426
# 2           2  1680.04          86.205        86.140                86.2444
# 3           3  1680.06          86.180        86.185                86.2462
# 4           4  1680.08          86.170        86.230                86.2486
#
#    Smooth Speed Leader    Spacing  \
# 0              86.1340  27.628521
# 1              86.1348  27.623119
# 2              86.1354  27.623431
# 3              86.1376  27.629303
# 4              86.1396  27.629145
#
#                                            file_path gap_setting  \
# 0  ../data/Polestar 2/Polestar/Short/0_desired/55...       Short
# 1  ../data/Polestar 2/Polestar/Short/0_desired/55...       Short
# 2  ../data/Polestar 2/Polestar/Short/0_desired/55...       Short
# 3  ../data/Polestar 2/Polestar/Short/0_desired/55...       Short
# 4  ../data/Polestar 2/Polestar/Short/0_desired/55...       Short
#
#    desired_speed  free_flow_speed  speed_fluctuation  v_follower   v_leader
# 0              0               55                 25   23.955000  23.926111
# 1              0               55                 25   23.956278  23.926333
# 2              0               55                 25   23.956778  23.926500
# 3              0               55                 25   23.957278  23.927111
# 4              0               55                 25   23.957944  23.927667

# %%
# Compute relative speed and spacing
df["delta_v"] = df["v_follower"] - df["v_leader"]
df["spacing"] = df["Spacing"]  # Already in meters

# Estimate time step and acceleration
df["dt"] = df["Time"].diff()
df["acc_follower"] = df["v_follower"].diff() / df["dt"]

# Drop the first row (NaN)
df_cleaned = df.dropna(subset=["dt", "acc_follower"])

df_cleaned.head()
# Out:
#    Unnamed: 0     Time  Speed Follower  Speed Leader  Smooth Speed Follower  \
# 1           1  1680.02          86.230        86.140                86.2426
# 2           2  1680.04          86.205        86.140                86.2444
# 3           3  1680.06          86.180        86.185                86.2462
# 4           4  1680.08          86.170        86.230                86.2486
# 5           5  1680.10          86.160        86.150                86.2492
#
#    Smooth Speed Leader    Spacing  \
# 1              86.1348  27.623119
# 2              86.1354  27.623431
# 3              86.1376  27.629303
# 4              86.1396  27.629145
# 5              86.1364  27.623431
#
#                                            file_path gap_setting  \
# 1  ../data/Polestar 2/Polestar/Short/0_desired/55...       Short
# 2  ../data/Polestar 2/Polestar/Short/0_desired/55...       Short
# 3  ../data/Polestar 2/Polestar/Short/0_desired/55...       Short
# 4  ../data/Polestar 2/Polestar/Short/0_desired/55...       Short
# 5  ../data/Polestar 2/Polestar/Short/0_desired/55...       Short
#
#    desired_speed  free_flow_speed  speed_fluctuation  v_follower   v_leader  \
# 1              0               55                 25   23.956278  23.926333
# 2              0               55                 25   23.956778  23.926500
# 3              0               55                 25   23.957278  23.927111
# 4              0               55                 25   23.957944  23.927667
# 5              0               55                 25   23.958111  23.926778
#
#     delta_v    spacing    dt  acc_follower
# 1  0.029944  27.623119  0.02      0.063889
# 2  0.030278  27.623431  0.02      0.025000
# 3  0.030167  27.629303  0.02      0.025000
# 4  0.030278  27.629145  0.02      0.033333
# 5  0.031333  27.623431  0.02      0.008333

# %%
# One-hot encode the 'gap_setting' column
gap_dummies = pd.get_dummies(df_cleaned['gap_setting'], prefix='gap')

# Combine all selected features
features = pd.concat([
    df_cleaned[["spacing", "delta_v", "v_follower", "speed_fluctuation"]],
    gap_dummies
], axis=1)

# Keep the same target: follower accelerationtest
target = df_cleaned["acc_follower"]

# %%
features['gap_Medium'] = False
features['gap_Long'] = False
features['gap_XLong'] = False

# %%
features
# Out:
#          spacing   delta_v  v_follower  speed_fluctuation  gap_Short  \
# 1      27.623119  0.029944   23.956278                 25       True
# 2      27.623431  0.030278   23.956778                 25       True
# 3      27.629303  0.030167   23.957278                 25       True
# 4      27.629145  0.030278   23.957944                 25       True
# 5      27.623431  0.031333   23.958111                 25       True
# ...          ...       ...         ...                ...        ...
# 36356  34.628382 -0.040944   23.953833                 45       True
# 36357  34.633406 -0.041000   23.954778                 45       True
# 36358  34.632396 -0.040111   23.955389                 45       True
# 36359  34.632396 -0.039556   23.955222                 45       True
# 36360  34.638432 -0.039889   23.954667                 45       True
#
#        gap_Medium  gap_Long  gap_XLong
# 1           False     False      False
# 2           False     False      False
# 3           False     False      False
# 4           False     False      False
# 5           False     False      False
# ...           ...       ...        ...
# 36356       False     False      False
# 36357       False     False      False
# 36358       False     False      False
# 36359       False     False      False
# 36360       False     False      False
#
# [36360 rows x 8 columns]

# %%
# spacing	delta_v	v_follower	speed_fluctuation	gap_Long	gap_Medium	gap_Short	gap_XLong

# %%
# Define the desired column order
gap_columns = ['gap_Long', 'gap_Medium', 'gap_Short', 'gap_XLong']

# Get the other columns in original order (excluding gap_columns)
other_columns = [col for col in features.columns if col not in gap_columns]

# Reorder the DataFrame
features = features[other_columns + gap_columns]

# %%
features
# Out:
#          spacing   delta_v  v_follower  speed_fluctuation  gap_Long  \
# 1      27.623119  0.029944   23.956278                 25     False
# 2      27.623431  0.030278   23.956778                 25     False
# 3      27.629303  0.030167   23.957278                 25     False
# 4      27.629145  0.030278   23.957944                 25     False
# 5      27.623431  0.031333   23.958111                 25     False
# ...          ...       ...         ...                ...       ...
# 36356  34.628382 -0.040944   23.953833                 45     False
# 36357  34.633406 -0.041000   23.954778                 45     False
# 36358  34.632396 -0.040111   23.955389                 45     False
# 36359  34.632396 -0.039556   23.955222                 45     False
# 36360  34.638432 -0.039889   23.954667                 45     False
#
#        gap_Medium  gap_Short  gap_XLong
# 1           False       True      False
# 2           False       True      False
# 3           False       True      False
# 4           False       True      False
# 5           False       True      False
# ...           ...        ...        ...
# 36356       False       True      False
# 36357       False       True      False
# 36358       False       True      False
# 36359       False       True      False
# 36360       False       True      False
#
# [36360 rows x 8 columns]

# %%
# Function to plot feature-target relationships for a specified index range
def plot_feature_target_range(features, target, start=0, end=100):
    plt.figure(figsize=(18, 5))

    # Slice the data for the specified range
    features_range = features.iloc[start:end]
    target_range = target.iloc[start:end]

    for i, column in enumerate(features_range.columns):
        plt.subplot(1, features.shape[1], i + 1)
        plt.scatter(features_range[column], target_range, alpha=0.6, s=20)
        plt.xlabel(column)
        plt.ylabel("Acceleration (m/s²)")
        plt.title(f"{column} vs Acceleration (Rows {start}–{end})")
        plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
plot_feature_target_range(features, target, start=0, end=1000)

# %%
# laod model
# Load the model from the file
rf_model_loaded = joblib.load("rf_model_acceleration.pkl")

# %%
# Predict and evaluate
y_pred = rf_model_loaded.predict(features)
rmse = mean_squared_error(target, y_pred)
r2 = r2_score(target, y_pred)

rmse, r2
# Out:
# (0.25134567802293634, 0.0757640939693971)

# %%
target
# Out:
# 1        0.063889
# 2        0.025000
# 3        0.025000
# 4        0.033333
# 5        0.008333
#            ...
# 36356    0.038889
# 36357    0.047222
# 36358    0.030556
# 36359   -0.008333
# 36360   -0.027778
# Name: acc_follower, Length: 36360, dtype: float64

# %%
y_pred
# Out:
# array([0.00919444, 0.00919444, 0.00866667, ..., 0.37466667, 0.37561111,
#        0.37419444], shape=(36360,))
